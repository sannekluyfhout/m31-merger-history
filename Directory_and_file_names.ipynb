# %%
import sys 
sys.path.append("/Users/users/wempe/lgsim")
from lgsim.postprocess_gadget import *
from pathlib import Path

# %%
fol = Path("/net/gaia2/data/users/wempe/rerun_169/")
folnames_new = sorted([x.parent for x in list(fol.glob("*/snapshot_209.hdf5"))])

# %%
# fol = Path("/net/gaia2/data/users/wempe/lr/")
# folnames_new = sorted([x.parent for x in list(fol.glob("*/snapshot_209.hdf5"))])
# #70 more LR simulations

# %%
fol = folnames_new[128]

# %%
print(fol) #mergers.nc
# Out:
# /net/gaia2/data/users/wempe/rerun_169/runz98.7_mcmc_1189

# %% [markdown]
# 59 M31 analogues: [5, 7, 9, 10, 26, 35, 36, 39, 43, 46, 51, 57, 60, 62, 63, 64, 70, 72, 73, 75, 77, 82, 85, 86, 87, 88, 93, 97, 110, 113, 116, 118, 124, 128, 138, 143, 144, 150, 152, 155, 159, 161, 163, 164, 174, 177, 181, 188, 189, 190, 191, 194, 195, 207, 209, 210, 215, 219, 224]

# %%
simulations1 = [5, 7, 9, 10, 26, 35, 36, 39, 43, 46, 51, 57, 60, 62, 63, 64, 70, 72, 73, 75, 77, 82, 85, 86, 87, 88, 93, 97, 110, 113, 116, 118, 124, 128, 138, 143, 144, 150, 152, 155, 159, 161, 163, 164]

# %%
simulations2 = [5, 8, 12, 19, 20, 21, 22, 25, 26, 38, 40, 41, 46, 50, 55]

# %%
for sim in simulations1:
    print(f"Simulation {sim}:")
    print(folnames_new[sim])
    print()
# Out:
# Simulation 5:
# /net/gaia2/data/users/wempe/rerun_169/runz98.10_mcmc_1419
#
# Simulation 7:
# /net/gaia2/data/users/wempe/rerun_169/runz98.10_mcmc_1579
#
# Simulation 9:
# /net/gaia2/data/users/wempe/rerun_169/runz98.10_mcmc_1739
#
# Simulation 10:
# /net/gaia2/data/users/wempe/rerun_169/runz98.10_mcmc_1819
#
# Simulation 26:
# /net/gaia2/data/users/wempe/rerun_169/runz98.11_mcmc_1909
#
# Simulation 35:
# /net/gaia2/data/users/wempe/rerun_169/runz98.12_mcmc_1499
#
# Simulation 36:
# /net/gaia2/data/users/wempe/rerun_169/runz98.12_mcmc_1579
#
# Simulation 39:
# /net/gaia2/data/users/wempe/rerun_169/runz98.12_mcmc_1819
#
# Simulation 43:
# /net/gaia2/data/users/wempe/rerun_169/runz98.12_mcmc_939
#
# Simulation 46:
# /net/gaia2/data/users/wempe/rerun_169/runz98.1_mcmc_1169
#
# Simulation 51:
# /net/gaia2/data/users/wempe/rerun_169/runz98.1_mcmc_1569
#
# Simulation 57:
# /net/gaia2/data/users/wempe/rerun_169/runz98.1_mcmc_2049
#
# Simulation 60:
# ...

# %%
for sim in simulations2:
    print(f"Simulation {sim+169}:")
    print(folnames_new[sim])
    print()
# Out:
# Simulation 174:
# /net/gaia2/data/users/wempe/rerun_169/runz98.10_mcmc_1419
#
# Simulation 177:
# /net/gaia2/data/users/wempe/rerun_169/runz98.10_mcmc_1659
#
# Simulation 181:
# /net/gaia2/data/users/wempe/rerun_169/runz98.10_mcmc_1979
#
# Simulation 188:
# /net/gaia2/data/users/wempe/rerun_169/runz98.11_mcmc_1349
#
# Simulation 189:
# /net/gaia2/data/users/wempe/rerun_169/runz98.11_mcmc_1429
#
# Simulation 190:
# /net/gaia2/data/users/wempe/rerun_169/runz98.11_mcmc_1509
#
# Simulation 191:
# /net/gaia2/data/users/wempe/rerun_169/runz98.11_mcmc_1589
#
# Simulation 194:
# /net/gaia2/data/users/wempe/rerun_169/runz98.11_mcmc_1829
#
# Simulation 195:
# /net/gaia2/data/users/wempe/rerun_169/runz98.11_mcmc_1909
#
# Simulation 207:
# /net/gaia2/data/users/wempe/rerun_169/runz98.12_mcmc_1739
#
# Simulation 209:
# /net/gaia2/data/users/wempe/rerun_169/runz98.12_mcmc_1899
#
# Simulation 210:
# /net/gaia2/data/users/wempe/rerun_169/runz98.12_mcmc_1979
#
# Simulation 215:
# ...
